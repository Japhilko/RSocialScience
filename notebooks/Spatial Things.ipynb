# %%
library(ggmap)
# Out:
# Loading required package: ggplot2

# %%
qmap("Mannheim B2,1")
# Out:
# Map from URL : http://maps.googleapis.com/maps/api/staticmap?center=Mannheim+B2,1&zoom=10&size=640x640&scale=2&maptype=terrain&language=en-EN&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Mannheim%20B2,1&sensor=false
# plot without title

# %% [markdown]
# ## Heaping

# %%
install.packages("raster")
# Out:
# Error in contrib.url(repos, "source"): trying to use CRAN without setting a mirror

# %%
library(sp)  # vector data
library(raster)  # raster data
library(rgdal)  # input/output, projections
library(rgeos)  # geometry ops
library(spdep)  # spatial dependence
# Out:
# Error in library(raster): there is no package called 'raster'
# Error in library(rgdal): there is no package called 'rgdal'
# Error in library(rgeos): there is no package called 'rgeos'
# Error in library(spdep): there is no package called 'spdep'
